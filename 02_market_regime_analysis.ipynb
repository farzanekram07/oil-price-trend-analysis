# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))

# %% [markdown]
# How does oil market behavior change across calm, trending, and volatile periods?

# %%
from src.data_loader import load_oil_data

# %%
df = load_oil_data()
# Out:
# [                       0%                       ]$5Y: possibly delisted; no price data found  (period=1mo) (Yahoo error = "No data found, symbol may be delisted")
# [**********************50%                       ]  2 of 4 completed$PERIOD: possibly delisted; no price data found  (period=1mo) (Yahoo error = "No data found, symbol may be delisted")
# $=: possibly delisted; no price data found  (period=1mo) (Yahoo error = "No data found, symbol may be delisted")
# [*********************100%***********************]  4 of 4 completed
#
# 3 Failed downloads:
# ['5Y', 'PERIOD', '=']: possibly delisted; no price data found  (period=1mo) (Yahoo error = "No data found, symbol may be delisted")

# %%
df.head(5)
# Out:
# Price      Adj Close            Close                        High      \
# Ticker            5Y   = PERIOD    5Y   =        CL=F PERIOD   5Y   =
# Date
# 2026-04-29       NaN NaN    NaN   NaN NaN  106.879997    NaN  NaN NaN
# 2026-04-30       NaN NaN    NaN   NaN NaN  105.070000    NaN  NaN NaN
# 2026-05-01       NaN NaN    NaN   NaN NaN  101.940002    NaN  NaN NaN
# 2026-05-04       NaN NaN    NaN   NaN NaN  106.419998    NaN  NaN NaN
# 2026-05-05       NaN NaN    NaN   NaN NaN  102.269997    NaN  NaN NaN
#
# Price                   ...         Low        Open                         \
# Ticker            CL=F  ...        CL=F PERIOD   5Y   =        CL=F PERIOD
# Date                    ...
# 2026-04-29  108.599998  ...   98.419998    NaN  NaN NaN   99.709999    NaN
# 2026-04-30  110.930000  ...  103.339996    NaN  NaN NaN  109.070000    NaN
# 2026-05-01  106.650002  ...   99.300003    NaN  NaN NaN  105.139999    NaN
# ...
